# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# MY NAME: **HIEN NGUYEN**
# OCCUPATION: BUSINESS ANALYST

# %% [markdown]
# _I am interested in Data Science because I want to know how to analyse data better. Particularly, I want to know how to apply tools & methodology in different datasets_

# %% [markdown]
# ### My code is a simple printing function from Python

# %%
X = ('Hello World')
print (X)
# Out:
# Hello World

# %% [markdown]
# This is Horizontal Rule
#
# ---
#
# This is Horizontal Rule
#
# ---
# [This is Hyperlink to Google Homepage](https://www.google.com "Google's Homepage")
#
# ---
#
# This is Syntax Highlight
#
# ```python
# X = ('Hello World')
# Print(X)
# ```
#
# ---
#
# > This is Blockqquotes
